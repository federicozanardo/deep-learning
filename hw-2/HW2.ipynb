# %% [markdown]
# #**HW 2: Optimize and train Deep Models**
#
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well known problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.  https://keras.io/

# %% [markdown]
# ##Exercise 2.1: Image Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layers Neural Network to perfrom classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import time

import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 



tf.random.set_seed(42)
# os.environ['TF_DETERMINISTIC_OPS']='1'

# %% [markdown]
# ### Load Data: IMDB dataset
#
# In this HW, we use the IMDB dataset that can be easily downloaded using Keras. The dataset contains 50,000 movie reviews from IMDB, labeled by sentiment (positive/negative). Reviews have been preprocessed, and each review is encoded as a sequence of word indexes. For convenience, the words are indexed by the overall frequency in the dataset, so that for example the integer "3" encodes the 3rd most frequent word in the data. For testing purposes, we will only consider the first 10,000  most common words.
# By default, the load_data method returns a breakdown of the dataset into training and test sets. Both these sets contain 25,000 samples. To also have a validation set, we split the test set in half.

# %%
num_words = 1000
(X_train, y_train), (X_test, y_test) = keras.datasets.imdb.load_data(num_words=num_words)
(X_valid, X_test) = X_test[:12500], X_test[12500:]
(y_valid, y_test) = y_test[:12500], y_test[12500:]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %% [markdown]
# In this HW we will consider a Deep Neural Network. The IMDB data consists in reviews, each one composed by a seqeunce of words. In order to encode each review in a single tensor with a fixed number of elements, we will use multi-hot encoding. Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
def multi_hot_encoder(dataset, num_word):
  dataset_multi_hot=[]
  for sequence in dataset:
    index, _ = tf.unique(sequence)
    dataset_multi_hot.append(tf.reduce_max(tf.one_hot(index-1, num_word, dtype=tf.int32), axis=0))
  dataset_multi_hot = tf.stack(dataset_multi_hot)
  return dataset_multi_hot

X_train = multi_hot_encoder(X_train,num_words)
X_test = multi_hot_encoder(X_test,num_words)
X_valid = multi_hot_encoder(X_valid,num_words)

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (keras.models.Sequential) and add four layers to it by calling its add() method:
#
#
# *   a input layer (tf.keras.Input) that is the first layer in your model. With this layer you should specify the input_shape argument, leaving out the batch size: (num_words,);
# *  a Dense layer (keras.layers.Dense) with 16 neurons, and the "relu" activation function;
# * another Dense layer with 16 neurons, also with the "relu" activation function;
# * a final Dense layer with 1 output neurons, and with the "sigmoid" activation (since we considering a binary classification task).

# %%
model = keras.models.Sequential()
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %% [markdown]
# Call the model's summary() method to check if the model has been built correctly. Also, try using keras.utils.plot_model() to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                16016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_imdb_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (?), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# Instaed of using *add()* method it is also possibile to define the model using the following syntax

# %%
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])
model.summary()
keras.utils.plot_model(model, "my_imdb_model.png", show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                16016
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its compile() method to specify the loss function and the optimizer to use.
#
# Since the model performs a binary classification task, we use the bynary cross-entropy as loss. As optimizer we use Adam.
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify metrics=["accuracy"].

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its fit() method, passing to it the input features (X_train) and the target classes (y_train). Set the number of epochs to 20.
# In order to validate our model we will also pass the validation data by setting validation_data=(X_valid, y_valid). Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the fit() method will return a History object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 782/782 [==============================] - 6s 4ms/step - loss: 0.6691 - accuracy: 0.5917 - val_loss: 0.5086 - val_accuracy: 0.7899
# Epoch 2/20
# 782/782 [==============================] - 3s 4ms/step - loss: 0.4609 - accuracy: 0.8105 - val_loss: 0.3856 - val_accuracy: 0.8406
# Epoch 3/20
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3556 - accuracy: 0.8580 - val_loss: 0.3534 - val_accuracy: 0.8515
# Epoch 4/20
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3298 - accuracy: 0.8647 - val_loss: 0.3407 - val_accuracy: 0.8543
# Epoch 5/20
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3148 - accuracy: 0.8714 - val_loss: 0.3377 - val_accuracy: 0.8555
# Epoch 6/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3055 - accuracy: 0.8712 - val_loss: 0.3344 - val_accuracy: 0.8565
# Epoch 7/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2989 - accuracy: 0.8771 - val_loss: 0.3344 - val_accuracy: 0.8562
# Epoch 8/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3030 - accuracy: 0.8742 - val_loss: 0.3344 - val_accuracy: 0.8557
# Epoch 9/20
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2970 - accuracy: 0.8784 - val_loss: 0.3352 - val_accuracy: 0.8549
# Epoch 10/20
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2928 - accuracy: 0.8781 - val_loss: 0.3355 - val_accuracy: 0.8552
# Epoch 11/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2966 - accuracy: 0.8797 - val_loss: 0.3366 - val_accuracy: 0.8539
# Epoch 12/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2865 - accuracy: 0.8849 - val_loss: 0.3373 - val_accuracy: 0.8549
# Epoch 13/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2954 - accuracy: 0.8803 - val_loss: 0.3393 - val_accuracy: 0.8543
# Epoch 14/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2856 - accuracy: 0.8837 - val_loss: 0.3387 - val_accuracy: 0.8536
# Epoch 15/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2884 - accuracy: 0.8822 - val_loss: 0.3398 - val_accuracy: 0.8538
# Epoch 16/20
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2878 - accuracy: 0.8806 - val_loss: 0.3405 - val_accuracy: 0.8534
# Epoch 17/20
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2871 - accuracy: 0.8821 - val_loss: 0.3418 - val_accuracy: 0.8546
# Epoch 18/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2822 - accuracy: 0.8861 - val_loss: 0.3427 - val_accuracy: 0.8542
# Epoch 19/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2847 - accuracy: 0.8863 - val_loss: 0.3433 - val_accuracy: 0.8526
# Epoch 20/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2792 - accuracy: 0.8863 - val_loss: 0.3445 - val_accuracy: 0.8531

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the "plot_learning_acc_and_loss" function because we will reuse it in the next steps.

# %%
def plot_learning_acc_and_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_acc_and_loss(history)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 391/391 [==============================] - 1s 2ms/step - loss: 0.3227 - accuracy: 0.8662
# [0.32265689969062805, 0.8662400245666504]

# %% [markdown]
# [TO COMPLETE] Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain which is the usefulness of the validation set. Insert the discussion in this cell.
#
# ### **Answer**
#
# **Test set** and **validation set** are two sets used for different purposes. When we train a deep learning algorithm we want to know how it performs on data that it hasn't never seen before. So we use a different set of data (test set) that the model has never seen during the training phase.
#
# The ability to perform well on data that the model has never seen is called **generalization**. We want a low *generalization error* (also known as *test error*) that is defined as the expected value of the error on a new input. The estimate of the generalization error is performed in a test set.
#
# Many machine learning algorithms have different settings to be set and they are useful to control the behaviour of the learning algorithm (for example, through them we can control the overfitting). These settings are called **hyper-parameters**. These values are not learned by the algorithm but they must be provided from outside.
#
# The main problem is that there are several possible values for a single hyper-parameter and choosing one over another could change the performance of the model. To find the hyper-parameters that allow the model to perform well, we have to estimate for each model (each model has different values for a specific subset of hyper-parameters of the model itself) on a set that is different from the training set. So we use the **validation set** (composed of examples coming from the same distribution as the training set). That set, it is used also to estimate the generalization error of each model, after the learning process has completed.
#
# Validating each model on a validation set permits to find the best model with the lowest generalization error and this also indicates which are the best hyper-parameters for the model.
# The test set is used to measure the performance of the final model (the model choosen after the validation phase) and it provides an unbiased estimate.
#
# It's important to measure the performance of the model on a test set and not on a validation set because the validation set is used during the building process of the model, thus the validation phase provides a biased estimate. For this reason, the test set is used to measure the performance of the final model and to get an unbiased estimate.

# %% [markdown]
# ## [TO COMPLETE] Exercise 2.2: Overfitting
#
# A common problem that occurs when you train a deep neural network is overfitting. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..
#
# [TO COMPLETE] In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %%
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])
#[TO COMPLETE] modify the previous model in order to obtain a new mdel that overfit the training data

#[TO COMPLETE] learning rate
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-2),
              metrics=["accuracy"])

#[TO COMPLETE] epochs
history = model.fit(X_train, y_train, epochs=150,
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.4177 - accuracy: 0.8026 - val_loss: 0.3462 - val_accuracy: 0.8403
# Epoch 2/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3198 - accuracy: 0.8613 - val_loss: 0.3417 - val_accuracy: 0.8535
# Epoch 3/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2795 - accuracy: 0.8807 - val_loss: 0.3516 - val_accuracy: 0.8480
# Epoch 4/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2651 - accuracy: 0.8821 - val_loss: 0.3643 - val_accuracy: 0.8495
# Epoch 5/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2331 - accuracy: 0.8980 - val_loss: 0.3862 - val_accuracy: 0.8411
# Epoch 6/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2023 - accuracy: 0.9132 - val_loss: 0.4266 - val_accuracy: 0.8367
# Epoch 7/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1727 - accuracy: 0.9286 - val_loss: 0.5284 - val_accuracy: 0.8313
# Epoch 8/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1488 - accuracy: 0.9397 - val_loss: 0.4898 - val_accuracy: 0.8326
# Epoch 9/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1268 - accuracy: 0.9528 - val_loss: 0.5308 - val_accuracy: 0.8266
# Epoch 10/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1099 - accuracy: 0.9584 - val_loss: 0.6057 - val_accuracy: 0.8269
# Epoch 11/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0945 - accuracy: 0.9640 - val_loss: 0.6232 - val_accuracy: 0.8276
# Epoch 12/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0853 - accuracy: 0.9683 - val_loss: 0.7198 - val_accuracy: 0.8271
# Epoch 13/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0793 - accuracy: 0.9723 - val_loss: 0.7962 - val_accuracy: 0.8251
# Epoch 14/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0727 - accuracy: 0.9735 - val_loss: 0.8414 - val_accuracy: 0.8268
# Epoch 15/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0606 - accuracy: 0.9767 - val_loss: 0.8874 - val_accuracy: 0.8234
# Epoch 16/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0560 - accuracy: 0.9789 - val_loss: 0.9623 - val_accuracy: 0.8180
# Epoch 17/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0530 - accuracy: 0.9793 - val_loss: 1.0199 - val_accuracy: 0.8190
# Epoch 18/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0489 - accuracy: 0.9808 - val_loss: 0.8898 - val_accuracy: 0.8233
# Epoch 19/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0454 - accuracy: 0.9833 - val_loss: 0.9647 - val_accuracy: 0.8233
# Epoch 20/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0436 - accuracy: 0.9844 - val_loss: 1.0412 - val_accuracy: 0.8145
# Epoch 21/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0437 - accuracy: 0.9844 - val_loss: 1.1075 - val_accuracy: 0.8164
# Epoch 22/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0381 - accuracy: 0.9863 - val_loss: 1.1181 - val_accuracy: 0.8218
# Epoch 23/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0317 - accuracy: 0.9886 - val_loss: 1.3563 - val_accuracy: 0.8272
# Epoch 24/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0354 - accuracy: 0.9860 - val_loss: 1.2307 - val_accuracy: 0.8221
# Epoch 25/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0348 - accuracy: 0.9868 - val_loss: 1.3235 - val_accuracy: 0.8190
# Epoch 26/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0293 - accuracy: 0.9884 - val_loss: 1.3834 - val_accuracy: 0.8183
# Epoch 27/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0323 - accuracy: 0.9871 - val_loss: 1.4316 - val_accuracy: 0.8210
# Epoch 28/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0259 - accuracy: 0.9896 - val_loss: 1.5263 - val_accuracy: 0.8235
# Epoch 29/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0278 - accuracy: 0.9901 - val_loss: 1.4937 - val_accuracy: 0.8184
# Epoch 30/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.
150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0217 - accuracy: 0.9926 - val_loss: 1.9700 - val_accuracy: 0.8234
# Epoch 62/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0135 - accuracy: 0.9949 - val_loss: 2.1239 - val_accuracy: 0.8170
# Epoch 63/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 2.8088 - val_accuracy: 0.8166
# Epoch 64/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0130 - accuracy: 0.9950 - val_loss: 2.4676 - val_accuracy: 0.8149
# Epoch 65/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0150 - accuracy: 0.9943 - val_loss: 2.3874 - val_accuracy: 0.8160
# Epoch 66/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0202 - accuracy: 0.9939 - val_loss: 2.0370 - val_accuracy: 0.8151
# Epoch 67/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 2.9534 - val_accuracy: 0.8174
# Epoch 68/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 2.3886 - val_accuracy: 0.8176
# Epoch 69/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0131 - accuracy: 0.9944 - val_loss: 2.5697 - val_accuracy: 0.8189
# Epoch 70/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0129 - accuracy: 0.9947 - val_loss: 2.2007 - val_accuracy: 0.8156
# Epoch 71/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 2.3597 - val_accuracy: 0.8190
# Epoch 72/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0113 - accuracy: 0.9952 - val_loss: 2.6949 - val_accuracy: 0.8166
# Epoch 73/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0209 - accuracy: 0.9930 - val_loss: 2.6137 - val_accuracy: 0.8201
# Epoch 74/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0115 - accuracy: 0.9956 - val_loss: 2.6863 - val_accuracy: 0.8179
# Epoch 75/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0143 - accuracy: 0.9944 - val_loss: 2.6331 - val_accuracy: 0.8201
# Epoch 76/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 3.0576 - val_accuracy: 0.8205
# Epoch 77/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 2.3072 - val_accuracy: 0.8212
# Epoch 78/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0133 - accuracy: 0.9945 - val_loss: 3.0901 - val_accuracy: 0.8208
# Epoch 79/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0110 - accuracy: 0.9956 - val_loss: 2.4400 - val_accuracy: 0.8230
# Epoch 80/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0094 - accuracy: 0.9959 - val_loss: 3.1460 - val_accuracy: 0.8189
# Epoch 81/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 3.0795 - val_accuracy: 0.8180
# Epoch 82/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0165 - accuracy: 0.9947 - val_loss: 2.6720 - val_accuracy: 0.8178
# Epoch 83/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0206 - accuracy: 0.9949 - val_loss: 3.1980 - val_accuracy: 0.8141
# Epoch 84/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0177 - accuracy: 0.9936 - val_loss: 2.6744 - val_accuracy: 0.8145
# Epoch 85/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 3.0134 - val_accuracy: 0.8174
# Epoch 86/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0069 - accuracy: 0.9970 - val_loss: 3.8293 - val_accuracy: 0.8171
# Epoch 87/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 3.2657 - val_accuracy: 0.8127
# Epoch 88/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 2.8278 - val_accuracy: 0.8145
# Epoch 89/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 3.5096 - val_accuracy: 0.8174
# Epoch 90/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 2.5810 - val_accuracy: 0.8161
# Epoch 91/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0212 - accuracy: 0.9949 - val_loss: 3.6480 - val_accuracy: 0.8166
# Epoch 92/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 3.3975 - val_accuracy: 0.8189
# Epoch 93/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0119 - accuracy: 0.9955 - val_loss: 3.2469 - val_accuracy: 0.8157
# Epoch 94/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.
150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 4.4110 - val_accuracy: 0.8114
# Epoch 132/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 3.3787 - val_accuracy: 0.8132
# Epoch 133/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 4.3846 - val_accuracy: 0.8136
# Epoch 134/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 5.1762 - val_accuracy: 0.8133
# Epoch 135/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 3.9557 - val_accuracy: 0.8102
# Epoch 136/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 4.5684 - val_accuracy: 0.8134
# Epoch 137/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 4.3422 - val_accuracy: 0.8158
# Epoch 138/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 4.2370 - val_accuracy: 0.8078
# Epoch 139/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0209 - accuracy: 0.9941 - val_loss: 4.2989 - val_accuracy: 0.8123
# Epoch 140/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0061 - accuracy: 0.9974 - val_loss: 5.7725 - val_accuracy: 0.8119
# Epoch 141/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 3.9957 - val_accuracy: 0.8114
# Epoch 142/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0075 - accuracy: 0.9970 - val_loss: 4.2517 - val_accuracy: 0.8091
# Epoch 143/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0093 - accuracy: 0.9965 - val_loss: 2.7561 - val_accuracy: 0.8127
# Epoch 144/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 3.8732 - val_accuracy: 0.8136
# Epoch 145/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 5.3099 - val_accuracy: 0.8127
# Epoch 146/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 4.2474 - val_accuracy: 0.8128
# Epoch 147/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 3.6451 - val_accuracy: 0.8162
# Epoch 148/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0121 - accuracy: 0.9964 - val_loss: 4.3583 - val_accuracy: 0.8104
# Epoch 149/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 4.3685 - val_accuracy: 0.8125
# Epoch 150/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0074 - accuracy: 0.9971 - val_loss: 4.4264 - val_accuracy: 0.8122
# Model Evaluation
# 391/391 [==============================] - 1s 2ms/step - loss: 4.2364 - accuracy: 0.8146
# [4.2363739013671875, 0.8146399855613708]

# %% [markdown]
# Define the plot_learning_curves function that plots inly the losses (not the accuracy).

# %%
def plot_learning_curves(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.epoch,history.history['loss'], label='train loss')
    plt.plot(history.epoch,history.history['val_loss'], label='valid loss')
    plt.legend()
    plt.title('loss')
    plt.grid(True)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### [TO COMPLETE] L1 norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow to remove the overfitting effect.

# %%
#In Keras is neccesary to add the regularizer by using the attribute kernel_regularizer
#to each layer whose weights will be considered in the Omega function.
#is it also possibile to consider the bias by using the attribute bias_regularizer 
#tf.keras.regularizers.l1(alpha) perfroms the L1-norm regularization

#[TO COMPLETE] copy the model that you previously defined that overfits the 
#trainnig data, and add the L1-norm regularization. Use a proper value for the
#alpha hyper-parameter, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1 

#In general, a layer that exploits L1-norm regularization is defined as follows:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE], kernel_regularizer=tf.keras.regularizers.l1([TO COMPLETE]))) 

#[TO COMPLETE]
alpha_l1 = 0.001

model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l1(alpha_l1)),
    keras.layers.Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l1(alpha_l1)),
    keras.layers.Dense(1, activation="sigmoid")
])

#[TO COMPLETE] learning rate
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-2),
              metrics=["accuracy"])

#[TO COMPLETE] epochs
history = model.fit(X_train, y_train, epochs=150,
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.9829 - accuracy: 0.7911 - val_loss: 0.6020 - val_accuracy: 0.8362
# Epoch 2/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5944 - accuracy: 0.8397 - val_loss: 0.5770 - val_accuracy: 0.8349
# Epoch 3/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5553 - accuracy: 0.8480 - val_loss: 0.5507 - val_accuracy: 0.8423
# Epoch 4/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5485 - accuracy: 0.8431 - val_loss: 0.5378 - val_accuracy: 0.8423
# Epoch 5/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.5441 - accuracy: 0.8454 - val_loss: 0.5829 - val_accuracy: 0.8196
# Epoch 6/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.8495 - val_loss: 0.5394 - val_accuracy: 0.8450
# Epoch 7/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.5346 - accuracy: 0.8502 - val_loss: 0.5483 - val_accuracy: 0.8398
# Epoch 8/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5420 - accuracy: 0.8476 - val_loss: 0.5614 - val_accuracy: 0.8366
# Epoch 9/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.5407 - accuracy: 0.8469 - val_loss: 0.5500 - val_accuracy: 0.8414
# Epoch 10/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5361 - accuracy: 0.8457 - val_loss: 0.5548 - val_accuracy: 0.8341
# Epoch 11/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5416 - accuracy: 0.8443 - val_loss: 0.5501 - val_accuracy: 0.8417
# Epoch 12/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.8528 - val_loss: 0.5341 - val_accuracy: 0.8488
# Epoch 13/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5432 - accuracy: 0.8460 - val_loss: 0.5452 - val_accuracy: 0.8403
# Epoch 14/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5440 - accuracy: 0.8435 - val_loss: 0.5419 - val_accuracy: 0.8434
# Epoch 15/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5333 - accuracy: 0.8470 - val_loss: 0.5435 - val_accuracy: 0.8382
# Epoch 16/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5354 - accuracy: 0.8469 - val_loss: 0.5634 - val_accuracy: 0.8291
# Epoch 17/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.8422 - val_loss: 0.5550 - val_accuracy: 0.8384
# Epoch 18/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5355 - accuracy: 0.8476 - val_loss: 0.5368 - val_accuracy: 0.8442
# Epoch 19/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.8442 - val_loss: 0.5489 - val_accuracy: 0.8390
# Epoch 20/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5386 - accuracy: 0.8471 - val_loss: 0.5423 - val_accuracy: 0.8409
# Epoch 21/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5411 - accuracy: 0.8464 - val_loss: 0.5370 - val_accuracy: 0.8429
# Epoch 22/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5400 - accuracy: 0.8431 - val_loss: 0.5367 - val_accuracy: 0.8451
# Epoch 23/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5349 - accuracy: 0.8519 - val_loss: 0.5509 - val_accuracy: 0.8386
# Epoch 24/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5369 - accuracy: 0.8470 - val_loss: 0.5586 - val_accuracy: 0.8308
# Epoch 25/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5386 - accuracy: 0.8422 - val_loss: 0.5428 - val_accuracy: 0.8408
# Epoch 26/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5363 - accuracy: 0.8458 - val_loss: 0.5410 - val_accuracy: 0.8440
# Epoch 27/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5387 - accuracy: 0
150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5347 - accuracy: 0.8493 - val_loss: 0.5419 - val_accuracy: 0.8388
# Epoch 128/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5347 - accuracy: 0.8485 - val_loss: 0.5444 - val_accuracy: 0.8410
# Epoch 129/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5334 - accuracy: 0.8476 - val_loss: 0.5426 - val_accuracy: 0.8427
# Epoch 130/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5263 - accuracy: 0.8522 - val_loss: 0.5493 - val_accuracy: 0.8339
# Epoch 131/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5332 - accuracy: 0.8460 - val_loss: 0.5349 - val_accuracy: 0.8452
# Epoch 132/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5272 - accuracy: 0.8506 - val_loss: 0.5444 - val_accuracy: 0.8411
# Epoch 133/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5435 - accuracy: 0.8428 - val_loss: 0.5334 - val_accuracy: 0.8486
# Epoch 134/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5272 - accuracy: 0.8533 - val_loss: 0.5592 - val_accuracy: 0.8338
# Epoch 135/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5289 - accuracy: 0.8516 - val_loss: 0.5939 - val_accuracy: 0.8191
# Epoch 136/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.5277 - accuracy: 0.8513 - val_loss: 0.5909 - val_accuracy: 0.8130
# Epoch 137/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5431 - accuracy: 0.8436 - val_loss: 0.5308 - val_accuracy: 0.8474
# Epoch 138/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5330 - accuracy: 0.8459 - val_loss: 0.5390 - val_accuracy: 0.8413
# Epoch 139/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.8480 - val_loss: 0.5335 - val_accuracy: 0.8462
# Epoch 140/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5346 - accuracy: 0.8514 - val_loss: 0.5346 - val_accuracy: 0.8449
# Epoch 141/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.5326 - accuracy: 0.8486 - val_loss: 0.5340 - val_accuracy: 0.8461
# Epoch 142/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5322 - accuracy: 0.8490 - val_loss: 0.5501 - val_accuracy: 0.8369
# Epoch 143/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5369 - accuracy: 0.8460 - val_loss: 0.5358 - val_accuracy: 0.8440
# Epoch 144/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5392 - accuracy: 0.8430 - val_loss: 0.5344 - val_accuracy: 0.8440
# Epoch 145/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5355 - accuracy: 0.8483 - val_loss: 0.5411 - val_accuracy: 0.8420
# Epoch 146/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5337 - accuracy: 0.8495 - val_loss: 0.5751 - val_accuracy: 0.8255
# Epoch 147/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5389 - accuracy: 0.8444 - val_loss: 0.5833 - val_accuracy: 0.8220
# Epoch 148/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5443 - accuracy: 0.8401 - val_loss: 0.5343 - val_accuracy: 0.8474
# Epoch 149/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.5364 - accuracy: 0.8424 - val_loss: 0.5417 - val_accuracy: 0.8413
# Epoch 150/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5309 - accuracy: 0.8489 - val_loss: 0.5475 - val_accuracy: 0.8402
# Model Evaluation
# 391/391 [==============================] - 1s 2ms/step - loss: 0.5267 - accuracy: 0.8510

# %% [markdown]
# ### [TO COMPLETE] L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainig data, and add the L2-norm regularization. Use proper values for the
#alpha hyper-parameters, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1

#In general, a layer that exploits L2-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE],kernel_regularizer=tf.keras.regularizers.l2([TO COMPLETE]))) 

#[TO COMPLETE]
alpha_l2 = 0.001

model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(alpha_l2)),
    keras.layers.Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(alpha_l2)),
    keras.layers.Dense(1, activation="sigmoid")
])

#[TO COMPLETE] learning rate
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-2),
              metrics=["accuracy"])

#[TO COMPLETE] epochs
history = model.fit(X_train, y_train, epochs=150,
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.
150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3901 - accuracy: 0.8541 - val_loss: 0.3996 - val_accuracy: 0.8507
# Epoch 126/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3856 - accuracy: 0.8535 - val_loss: 0.4485 - val_accuracy: 0.8231
# Epoch 127/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3941 - accuracy: 0.8510 - val_loss: 0.4102 - val_accuracy: 0.8446
# Epoch 128/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3960 - accuracy: 0.8505 - val_loss: 0.4045 - val_accuracy: 0.8458
# Epoch 129/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3895 - accuracy: 0.8547 - val_loss: 0.4048 - val_accuracy: 0.8449
# Epoch 130/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3869 - accuracy: 0.8567 - val_loss: 0.4352 - val_accuracy: 0.8226
# Epoch 131/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3928 - accuracy: 0.8518 - val_loss: 0.4045 - val_accuracy: 0.8458
# Epoch 132/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3890 - accuracy: 0.8551 - val_loss: 0.4010 - val_accuracy: 0.8457
# Epoch 133/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.4038 - accuracy: 0.8460 - val_loss: 0.4010 - val_accuracy: 0.8470
# Epoch 134/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3883 - accuracy: 0.8557 - val_loss: 0.4060 - val_accuracy: 0.8476
# Epoch 135/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3917 - accuracy: 0.8539 - val_loss: 0.4594 - val_accuracy: 0.8172
# Epoch 136/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3896 - accuracy: 0.8532 - val_loss: 0.4013 - val_accuracy: 0.8412
# Epoch 137/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.4007 - accuracy: 0.8463 - val_loss: 0.3974 - val_accuracy: 0.8470
# Epoch 138/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3957 - accuracy: 0.8508 - val_loss: 0.4053 - val_accuracy: 0.8424
# Epoch 139/150
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3957 - accuracy: 0.8501 - val_loss: 0.4124 - val_accuracy: 0.8405
# Epoch 140/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3934 - accuracy: 0.8517 - val_loss: 0.4002 - val_accuracy: 0.8444
# Epoch 141/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3941 - accuracy: 0.8529 - val_loss: 0.4126 - val_accuracy: 0.8394
# Epoch 142/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3970 - accuracy: 0.8536 - val_loss: 0.4324 - val_accuracy: 0.8340
# Epoch 143/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3999 - accuracy: 0.8509 - val_loss: 0.4083 - val_accuracy: 0.8442
# Epoch 144/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3968 - accuracy: 0.8498 - val_loss: 0.4002 - val_accuracy: 0.8479
# Epoch 145/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3925 - accuracy: 0.8520 - val_loss: 0.4023 - val_accuracy: 0.8457
# Epoch 146/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3959 - accuracy: 0.8501 - val_loss: 0.3978 - val_accuracy: 0.8482
# Epoch 147/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3962 - accuracy: 0.8506 - val_loss: 0.4215 - val_accuracy: 0.8355
# Epoch 148/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.4030 - accuracy: 0.8463 - val_loss: 0.4027 - val_accuracy: 0.8426
# Epoch 149/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3972 - accuracy: 0.8492 - val_loss: 0.4233 - val_accuracy: 0.8362
# Epoch 150/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3956 - accuracy: 0.8517 - val_loss: 0.4008 - val_accuracy: 0.8460
# Model Evaluation
# 391/391 [==============================] - 1s 2ms/step - loss: 0.3815 - accuracy: 0.8584

# %% [markdown]
# ###[TO COMPLETE] Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (patience hyper-parameter), it stops the training phase.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainnig data
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])

#[TO COMPLETE] learning rate
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-2),
              metrics=["accuracy"])

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the Eraly stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=8), # [TO COMPLETE] play with patience and find the value that prevents the model from overfitting.

    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

#[TO COMPLETE] epochs
history = model.fit(X_train, y_train, epochs=150,
                    validation_data=(X_valid, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.4143 - accuracy: 0.8136 - val_loss: 0.3437 - val_accuracy: 0.8478
# Epoch 2/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3168 - accuracy: 0.8641 - val_loss: 0.3391 - val_accuracy: 0.8530
# Epoch 3/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2756 - accuracy: 0.8834 - val_loss: 0.3428 - val_accuracy: 0.8459
# Epoch 4/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.2485 - accuracy: 0.8975 - val_loss: 0.3696 - val_accuracy: 0.8458
# Epoch 5/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2126 - accuracy: 0.9138 - val_loss: 0.4091 - val_accuracy: 0.8380
# Epoch 6/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.1687 - accuracy: 0.9359 - val_loss: 0.4134 - val_accuracy: 0.8298
# Epoch 7/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.1330 - accuracy: 0.9502 - val_loss: 0.4833 - val_accuracy: 0.8275
# Epoch 8/150
# 782/782 [==============================] - 3s 4ms/step - loss: 0.1095 - accuracy: 0.9569 - val_loss: 0.5541 - val_accuracy: 0.8242
# Epoch 9/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0823 - accuracy: 0.9695 - val_loss: 0.5957 - val_accuracy: 0.8262
# Epoch 10/150
# 782/782 [==============================] - 3s 3ms/step - loss: 0.0719 - accuracy: 0.9747 - val_loss: 0.6883 - val_accuracy: 0.8235
# Model Evaluation
# 391/391 [==============================] - 1s 2ms/step - loss: 0.3266 - accuracy: 0.8611

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(1, activation="sigmoid")
                                     ])
    model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train, y_train,
                        validation_data=(X_valid, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
    print("evaluation on test set")
    model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 782/782 [==============================] - 3s 4ms/step - loss: 0.6654 - accuracy: 0.5814 - val_loss: 0.4753 - val_accuracy: 0.8074
# Epoch 2/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.4283 - accuracy: 0.8266 - val_loss: 0.3704 - val_accuracy: 0.8462
# Epoch 3/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3395 - accuracy: 0.8621 - val_loss: 0.3485 - val_accuracy: 0.8534
# Epoch 4/10
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3216 - accuracy: 0.8653 - val_loss: 0.3393 - val_accuracy: 0.8567
# Epoch 5/10
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3102 - accuracy: 0.8740 - val_loss: 0.3378 - val_accuracy: 0.8571
# Epoch 6/10
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3019 - accuracy: 0.8756 - val_loss: 0.3353 - val_accuracy: 0.8562
# Epoch 7/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2960 - accuracy: 0.8788 - val_loss: 0.3356 - val_accuracy: 0.8562
# Epoch 8/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3010 - accuracy: 0.8765 - val_loss: 0.3360 - val_accuracy: 0.8551
# evaluation on test set
# 391/391 [==============================] - 1s 2ms/step - loss: 0.3170 - accuracy: 0.8656
# Epoch 1/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.4113 - accuracy: 0.8135 - val_loss: 0.3384 - val_accuracy: 0.8513
# Epoch 2/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3187 - accuracy: 0.8599 - val_loss: 0.3431 - val_accuracy: 0.8503
# Epoch 3/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.2839 - accuracy: 0.8771 - val_loss: 0.3513 - val_accuracy: 0.8486
# evaluation on test set
# 391/391 [==============================] - 1s 2ms/step - loss: 0.3284 - accuracy: 0.8597
# Epoch 1/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.7537 - accuracy: 0.5033 - val_loss: 0.6932 - val_accuracy: 0.5053
# Epoch 2/10
# 782/782 [==============================] - 2s 3ms/step - loss: 0.6951 - accuracy: 0.5027 - val_loss: 0.6931 - val_accuracy: 0.5053
# Epoch 3/10
# 782/782 [==============================] - 2s 3ms/step - loss: 0.6951 - accuracy: 0.4922 - val_loss: 0.7039 - val_accuracy: 0.4947
# Epoch 4/10
# 782/782 [==============================] - 2s 3ms/step - loss: 0.6952 - accuracy: 0.5024 - val_loss: 0.6975 - val_accuracy: 0.4947
# evaluation on test set
# 391/391 [==============================] - 1s 2ms/step - loss: 0.6957 - accuracy: 0.5053

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_acc_and_loss(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# ### [TO COMPLETE] GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use the GridSearchCV method from scikit-learn.

# %% [markdown]
# Let's Create a build_model() function that takes two arguments, n_neurons, learning_rate, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time requirements of the process we will consider only these two hyper-paramters.
#
# [TO COMPLETE] in the following code cell define the build_model function.

# %%
def build_model(n_units=30, learning_rate=1e-3):
    # The function has to build a model similar to the ones we used in previuous execises:
    #- a input layer 
    #- one or two Dense layers composed of n_units and that exploit Relu activation function 
    #- the output layer that uses the sigmoid activation function
    # Then, the model has to be compiled.
    model = keras.models.Sequential([
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(1, activation="sigmoid")
                                     ])
    
    # [TO COMPLETE] Then, the model has to be compiled.
    model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])

    return model

    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [8, 16, 20], # [TO COMPLETE] insert a list that contains few (2 or 3) reasonable value
    "learning_rate": [1e-2, 1e-3, 1e-4] # [TO COMPLETE] insert a list that contains few (2 or 3) reasonable values
    # Check how the time required to perform GRID search increases when increasing the number of values for each hyper-parameter.
}

# %% [markdown]
# Use a sklearn.model_selection.GridSearchCV to search the hyperparameter space of your KerasRegressor

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train.numpy(), y_train, epochs=10,#The number of epochs can be modified (check what happens by increasing it)
                validation_data=(X_valid.numpy(), y_valid))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 3s 3ms/step - loss: 0.4439 - accuracy: 0.7907 - val_loss: 0.3398 - val_accuracy: 0.8502
# Epoch 2/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3086 - accuracy: 0.8686 - val_loss: 0.3394 - val_accuracy: 0.8520
# Epoch 3/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2904 - accuracy: 0.8770 - val_loss: 0.3462 - val_accuracy: 0.8474
# Epoch 4/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2841 - accuracy: 0.8781 - val_loss: 0.3495 - val_accuracy: 0.8450
# Epoch 5/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2668 - accuracy: 0.8867 - val_loss: 0.3666 - val_accuracy: 0.8440
# Epoch 6/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2623 - accuracy: 0.8930 - val_loss: 0.3645 - val_accuracy: 0.8414
# Epoch 7/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2612 - accuracy: 0.8898 - val_loss: 0.3709 - val_accuracy: 0.8418
# Epoch 8/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2496 - accuracy: 0.8971 - val_loss: 0.3897 - val_accuracy: 0.8415
# Epoch 9/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2438 - accuracy: 0.9008 - val_loss: 0.3755 - val_accuracy: 0.8384
# Epoch 10/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2415 - accuracy: 0.9010 - val_loss: 0.4005 - val_accuracy: 0.8378
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8460
# Epoch 1/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4446 - accuracy: 0.7861 - val_loss: 0.3358 - val_accuracy: 0.8515
# Epoch 2/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3087 - accuracy: 0.8723 - val_loss: 0.3361 - val_accuracy: 0.8542
# Epoch 3/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2997 - accuracy: 0.8726 - val_loss: 0.3479 - val_accuracy: 0.8449
# Epoch 4/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2905 - accuracy: 0.8722 - val_loss: 0.3472 - val_accuracy: 0.8481
# Epoch 5/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2810 - accuracy: 0.8766 - val_loss: 0.3479 - val_accuracy: 0.8484
# Epoch 6/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2771 - accuracy: 0.8796 - val_loss: 0.3506 - val_accuracy: 0.8474
# Epoch 7/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.
# Epoch 7/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2937 - accuracy: 0.8784 - val_loss: 0.3406 - val_accuracy: 0.8560
# Epoch 8/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2929 - accuracy: 0.8793 - val_loss: 0.3414 - val_accuracy: 0.8532
# Epoch 9/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2897 - accuracy: 0.8806 - val_loss: 0.3418 - val_accuracy: 0.8528
# Epoch 10/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2838 - accuracy: 0.8836 - val_loss: 0.3431 - val_accuracy: 0.8530
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3409 - accuracy: 0.8558
# Epoch 1/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6676 - accuracy: 0.5835 - val_loss: 0.5166 - val_accuracy: 0.7809
# Epoch 2/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4645 - accuracy: 0.8145 - val_loss: 0.4008 - val_accuracy: 0.8319
# Epoch 3/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3712 - accuracy: 0.8485 - val_loss: 0.3629 - val_accuracy: 0.8471
# Epoch 4/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3352 - accuracy: 0.8625 - val_loss: 0.3488 - val_accuracy: 0.8546
# Epoch 5/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3140 - accuracy: 0.8712 - val_loss: 0.3433 - val_accuracy: 0.8552
# Epoch 6/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3045 - accuracy: 0.8745 - val_loss: 0.3404 - val_accuracy: 0.8554
# Epoch 7/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2983 - accuracy: 0.8755 - val_loss: 0.3400 - val_accuracy: 0.8562
# Epoch 8/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2991 - accuracy: 0.8787 - val_loss: 0.3398 - val_accuracy: 0.8550
# Epoch 9/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2906 - accuracy: 0.8822 - val_loss: 0.3405 - val_accuracy: 0.8546
# Epoch 10/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2901 - accuracy: 0.8821 - val_loss: 0.3423 - val_accuracy: 0.8530
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8608
# Epoch 1/10
# 782/782 [==============================] - 3s 4ms/step - loss: 0.6732 - accuracy: 0.5648 - val_loss: 0.5135 - val_accuracy: 0.7786
# Epoch 2/10
# 782/782 [==============================] - 3s 4ms/step - loss: 0.4719 - accuracy: 0.7995 - val_loss: 0.3983 - val_accuracy: 0.8329
# Epoch 3/10
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3703 - accuracy: 0.8486 - val_loss: 0.3621 - val_accuracy: 0.8496
# Epoch 4/10
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3383 - accuracy: 0.8587 - val_loss: 0.3456 - val_accuracy: 0.8563
# Epoch 5/10
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3210 - accuracy: 0.8699 - val_loss: 0.3414 - val_accuracy: 0.8566
# Epoch 6/10
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3100 - accuracy: 0.8714 - val_loss: 0.3367 - val_accuracy: 0.8578
# Epoch 7/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3018 - accuracy: 0.8765 - val_loss: 0.3360 - val_accuracy: 0.8580
# Epoch 8/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3056 - accuracy: 0.8726 - val_loss: 0.3360 - val_accuracy: 0.8570
# Epoch 9/10
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3003 - accuracy: 0.8761 - val_loss: 0.3362 - val_accuracy: 0.8575
# Epoch 10/10
# 782/782 [==============================] - 3s 4ms/step - loss: 0.2966 - accuracy: 0.8746 - val_loss: 0.3367 - val_accuracy: 0.8570
# GridSearchCV(cv=None, error_score=nan,
#              estimator=<tensorflow.python.keras.wrappers.scikit_learn.KerasRegressor object at 0x7f8023bfe590>,
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.01, 0.001, 0.0001],
#                          'n_units': [8, 16, 20]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# Print the best hyper-parameters, and evealuate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test, y_test)
# Out:
# {'learning_rate': 0.0001, 'n_units': 8}
# 391/391 [==============================] - 1s 2ms/step - loss: 0.3169 - accuracy: 0.8658
# [0.31689807772636414, 0.8658400177955627]
